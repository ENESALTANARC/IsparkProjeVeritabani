-- %% [markdown]
-- # [IsPark_Proje]

-- %%
USE [master]
GO

-- %%
/****** Object:  Database [IsPark_Proje]    Script Date: 31.08.2022 11:41:10 ******/
CREATE DATABASE [IsPark_Proje]
 CONTAINMENT = NONE
 ON  PRIMARY 
( NAME = N'IsPark_Proje', FILENAME = N'C:\Program Files\Microsoft SQL Server\MSSQL14.AA\MSSQL\DATA\IsPark_Proje.mdf' , SIZE = 8192KB , MAXSIZE = UNLIMITED, FILEGROWTH = 65536KB )
 LOG ON 
( NAME = N'IsPark_Proje_log', FILENAME = N'C:\Program Files\Microsoft SQL Server\MSSQL14.AA\MSSQL\DATA\IsPark_Proje_log.ldf' , SIZE = 8192KB , MAXSIZE = 2048GB , FILEGROWTH = 65536KB )
GO
ALTER DATABASE [IsPark_Proje] SET COMPATIBILITY_LEVEL = 140
GO
IF (1 = FULLTEXTSERVICEPROPERTY('IsFullTextInstalled'))
begin
EXEC [IsPark_Proje].[dbo].[sp_fulltext_database] @action = 'enable'
end
GO
ALTER DATABASE [IsPark_Proje] SET ANSI_NULL_DEFAULT OFF 
GO
ALTER DATABASE [IsPark_Proje] SET ANSI_NULLS OFF 
GO
ALTER DATABASE [IsPark_Proje] SET ANSI_PADDING OFF 
GO
ALTER DATABASE [IsPark_Proje] SET ANSI_WARNINGS OFF 
GO
ALTER DATABASE [IsPark_Proje] SET ARITHABORT OFF 
GO
ALTER DATABASE [IsPark_Proje] SET AUTO_CLOSE OFF 
GO
ALTER DATABASE [IsPark_Proje] SET AUTO_SHRINK OFF 
GO
ALTER DATABASE [IsPark_Proje] SET AUTO_UPDATE_STATISTICS ON 
GO
ALTER DATABASE [IsPark_Proje] SET CURSOR_CLOSE_ON_COMMIT OFF 
GO
ALTER DATABASE [IsPark_Proje] SET CURSOR_DEFAULT  GLOBAL 
GO
ALTER DATABASE [IsPark_Proje] SET CONCAT_NULL_YIELDS_NULL OFF 
GO
ALTER DATABASE [IsPark_Proje] SET NUMERIC_ROUNDABORT OFF 
GO
ALTER DATABASE [IsPark_Proje] SET QUOTED_IDENTIFIER OFF 
GO
ALTER DATABASE [IsPark_Proje] SET RECURSIVE_TRIGGERS OFF 
GO
ALTER DATABASE [IsPark_Proje] SET  DISABLE_BROKER 
GO
ALTER DATABASE [IsPark_Proje] SET AUTO_UPDATE_STATISTICS_ASYNC OFF 
GO
ALTER DATABASE [IsPark_Proje] SET DATE_CORRELATION_OPTIMIZATION OFF 
GO
ALTER DATABASE [IsPark_Proje] SET TRUSTWORTHY OFF 
GO
ALTER DATABASE [IsPark_Proje] SET ALLOW_SNAPSHOT_ISOLATION OFF 
GO
ALTER DATABASE [IsPark_Proje] SET PARAMETERIZATION SIMPLE 
GO
ALTER DATABASE [IsPark_Proje] SET READ_COMMITTED_SNAPSHOT OFF 
GO
ALTER DATABASE [IsPark_Proje] SET HONOR_BROKER_PRIORITY OFF 
GO
ALTER DATABASE [IsPark_Proje] SET RECOVERY SIMPLE 
GO
ALTER DATABASE [IsPark_Proje] SET  MULTI_USER 
GO
ALTER DATABASE [IsPark_Proje] SET PAGE_VERIFY CHECKSUM  
GO
ALTER DATABASE [IsPark_Proje] SET DB_CHAINING OFF 
GO
ALTER DATABASE [IsPark_Proje] SET FILESTREAM( NON_TRANSACTED_ACCESS = OFF ) 
GO
ALTER DATABASE [IsPark_Proje] SET TARGET_RECOVERY_TIME = 60 SECONDS 
GO
ALTER DATABASE [IsPark_Proje] SET DELAYED_DURABILITY = DISABLED 
GO
ALTER DATABASE [IsPark_Proje] SET QUERY_STORE = OFF
GO

-- %% [markdown]
-- # [dbo].[IsparkTbl]

-- %%
USE [IsPark_Proje]
GO

-- %%
/****** Object:  Table [dbo].[IsparkTbl]    Script Date: 31.08.2022 11:41:10 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[IsparkTbl](
	[ID] [int] IDENTITY(1,1) NOT NULL,
	[ParkID] [smallint] NULL,
	[ParkName] [varchar](100) NULL,
	[ParkTypeID] [smallint] NULL,
	[ParkType] [varchar](50) NULL,
	[ParkCapacity] [smallint] NULL,
	[WorkHours] [varchar](300) NULL,
	[RegionID] [smallint] NULL,
	[Region] [varchar](50) NULL,
	[SubRegionID] [smallint] NULL,
	[SubRegion] [varchar](50) NULL,
	[LocationID] [smallint] NULL,
	[LocationCode] [smallint] NULL,
	[LocationName] [varchar](100) NULL,
	[BoroughID] [smallint] NULL,
	[Borough] [varchar](100) NULL,
	[Adress] [varchar](300) NULL,
	[Point] [varchar](100) NULL,
	[Polygon] [varchar](8000) NULL,
	[Lat] [varchar](50) NULL,
	[Lon] [varchar](50) NULL,
	[MonthlyPrice] [float] NULL,
	[FreeParkingTime] [smallint] NULL,
	[Price] [varchar](700) NULL,
	[ParkAndGoPoint] [smallint] NULL,
 CONSTRAINT [PK_IsparkTbl] PRIMARY KEY CLUSTERED 
(
	[ID] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [IsPark_Proje]

-- %%
USE [master]
GO

-- %%
ALTER DATABASE [IsPark_Proje] SET  READ_WRITE 
GO
